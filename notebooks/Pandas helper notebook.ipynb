# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Compare your response with "correct" response (i.e., make your own cross-tabulation)

# %%
data = pd.read_csv('billboard.csv', encoding='latin-1')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data = pd.read_csv('billboard.csv', encoding='latin-1')
#
# File ~/miniforge3/envs/AudioTechII/lib/python3.9/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/AudioTechII/lib/python3.9/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/miniforge3/envs/AudioTechII/lib/python3.9/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~/miniforge3/envs/AudioTechII/lib/python3.9/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~/miniforge3/envs/AudioTechII/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniforge3/envs/AudioTechII/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File ~/miniforge3/envs/AudioTechII/lib/python3.9/site-packages/pandas/io/common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'billboard.csv'

# %%
data.head()
# Out:
#    year      artist.inverted                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre date.entered date.peaked  x1st.week  x2nd.week  x3rd.week  ...  \
# 0  Rock   2000-09-23  2000-11-18         78       63.0       49.0  ...
# 1  Rock   2000-02-12  2000-04-08         15        8.0        6.0  ...
# 2  Rock   1999-10-23  2000-01-29         71       48.0       43.0  ...
# 3  Rock   2000-08-12  2000-09-16         41       23.0       18.0  ...
# 4  Rock   2000-08-05  2000-10-14         57       47.0       45.0  ...
#
#    x67th.week  x68th.week  x69th.week  x70th.week  x71st.week  x72nd.week  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    x73rd.week  x74th.week  x75th.week  x76th.week
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN
#
# [5 rows x 83 columns]

# %%
len(data)
# Out:
# 317

# %%
# find total list of unique elements
genres = data.genre.unique()
genres
# Out:
# array(['Rock', 'Latin', 'Country', 'Rap', 'Pop', 'Electronica', 'Jazz',
#        'R&B', 'Reggae', 'Gospel'], dtype=object)

# %%
# get actual probability distribution of data
data.genre.value_counts(normalize=True)
# Out:
# Rock           0.432177
# Country        0.233438
# Rap            0.182965
# R&B            0.072555
# Latin          0.028391
# Pop            0.028391
# Electronica    0.012618
# Jazz           0.003155
# Reggae         0.003155
# Gospel         0.003155
# Name: genre, dtype: float64

# %%
# Making fake data - your model will create real data!!
import random

my_guesses = random.choices(genres, weights=data.genre.value_counts(normalize=True), k=317)
my_guesses
# Out:
# ['Country',
#  'Electronica',
#  'Latin',
#  'Latin',
#  'Rap',
#  'Latin',
#  'Latin',
#  'Rock',
#  'Latin',
#  'Country',
#  'Rock',
#  'Rock',
#  'Rock',
#  'Country',
#  'Rock',
#  'Country',
#  'Rap',
#  'Pop',
#  'Latin',
#  'Rock',
#  'Rock',
#  'Rock',
#  'Country',
#  'Country',
#  'Rap',
#  'Latin',
#  'Rock',
#  'Rock',
#  'Rock',
#  'Rock',
#  'Country',
#  'Rock',
#  'Latin',
#  'Rock',
#  'Rock',
#  'Rap',
#  'Rock',
#  'Pop',
#  'Rock',
#  'Rock',
#  'Latin',
#  'Latin',
#  'Country',
#  'Rock',
#  'Rap',
#  'Rock',
#  'Country',
#  'Rap',
#  'Rock',
#  'Latin',
#  'Rock',
#  'Rock',
#  'Rock',
#  'Country',
#  'Country',
#  'Latin',
#  'Rap',
#  'Rock',
#  'Latin',
#  'Country',
#  'Latin',
#  'Rock',
#  'Country',
#  'Latin',
#  'Rock',
#  'Country',
#  'Rock',
#  'Latin',
#  'Country',
#  'Latin',
#  'Rock',
#  'Country',
#  'Rock',
#  'Rock',
#  'Country',
#  'Latin',
#  'Pop',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Country',
#  'Country',
#  'Country',
#  'Rock',
#  'Rock',
#  'Latin',
#  'Rock',
#  'Rock',
#  'Rap',
#  'Rock',
#  'Country',
#  'Rock',
#  'Rock',
#  'Rap',
#  'Latin',
#  'Rap',
#  'Rock',
#  'Rock',
#  'Rock',
#  'Rock',
#  'Country',
#  'Country',
#  'Country',
#  'Rock',
#  'Rock',
#  'Country',
#  'Latin',
#  'Country',
#  'Pop',
#  'Country',
#  'Rock',
#  'Rock',
#  'Rock',
#  'Electronica',
#  'Rap',
#  'Rock',
#  'Rock',
#  'Pop',
#  'Reggae',
#  'Country',
#  'Rap',
#  'Rock',
#  'Rock',
#  'Country',
#  'Rock',
#  'Country',
#  'Rock',
#  'Rock',
#  'Rock',
#  'Rock',
#  'Electronica',
#  'Rock',
#  'Rock',
#  'Country',
#  'Latin',
#  'Latin',
#  'Electronica',
#  'Country',
#  'Latin',
#  'Country',
#  'Country',
#  'Rock',
#  'Rock',
#  'Rap',
#  'Rock',
#  'Rock',
#  'Rock',
#  'Rock',
#  'Rock',
#  'Rock',
#  'Latin',
#  'Country',
#  'Latin',
#  'Electronica',
#  'Country',
#  'Latin',
#  'Rock',
#  'Latin',
#  'Rap',
#  'Country',
#  'Rock',
#  'Country',
#  'Rock',
#  'Rap',
#  'Rock',
#  'Rap',
#  'Country',
#  'Electronica',
#  'Country',
#  'Rock',
#  'Country',
#  'Country',
#  'Latin',
#  'Rock',
#  'Rock',
#  'Rock',
#  'Latin',
#  'Country',
#  'Rap',
#  'Latin',
#  'Rap',
#  'Latin',
#  'Latin',
#  'Rap',
#  'Latin',
#  'Country',
#  'Latin',
#  'Rock',
#  'Country',
#  'Pop',
#  'Country',
#  'Rock',
#  'Latin',
#  'Rock',
#  'Rock',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Latin',
#  'Country',
#  'Rap',
#  'Rock',
#  'Rap',
#  'Rock',
#  'Rock',
#  'Rap',
#  'Country',
#  'Rock',
#  'Rock',
#  'Rock',
#  'Rock',
#  'Rap',
#  'Rap',
#  'Latin',
#  'Rock',
#  'Latin',
#  'Gospel',
#  'Latin',
#  'Country',
#  'Country',
#  'Country',
#  'Pop',
#  'Latin',
#  'Latin',
#  'Rock',
#  'Rock',
#  'Rock',
#  'Country',
#  'Latin',
#  'Rock',
#  'Country',
#  'Rock',
#  'Pop',
#  'Rock',
#  'Rock',
#  'Latin',
#  'Latin',
#  'Country',
#  'Rock',
#  'Rock',
#  'Country',
#  'Latin',
#  'Electronica',
#  'Rock',
#  'Rock',
#  'Latin',
#  'Country',
#  'Country',
#  'Latin',
#  'Rock',
#  'Latin',
#  'Rock',
#  'Rap',
#  'Country',
#  'Latin',
#  'Pop',
#  'Rock',
#  'Rock',
#  'Latin',
#  'Country',
#  'Latin',
#  'Country',
#  'Country',
#  'Country',
#  'Rap',
#  'Rock',
#  'R&B',
#  'Rock',
#  'Electronica',
#  'Latin',
#  'Country',
#  'Rock',
#  'Latin',
#  'Rock',
#  'Country',
#  'Latin',
#  'Country',
#  'Rap',
#  'Latin',
#  'Rock',
#  'Rap',
#  'Rock',
#  'Country',
#  'Latin',
#  'Rap',
#  'Rock',
#  'Rock',
#  'Latin',
#  'Rock',
#  'Rock',
#  'Rock',
#  'Latin',
#  'Country',
#  'Latin',
#  'Rock',
#  'Latin',
#  'Country',
#  'Rock',
#  'Rock',
#  'Country',
#  'Rap',
#  'Latin',
#  'Latin',
#  'Rap',
#  'Country',
#  'Latin',
#  'Rock',
#  'Latin',
#  'Latin',
#  'Rock',
#  'Rock',
#  'Rock',
#  'Latin',
#  'Rock',
#  'Rock',
#  'Latin']

# %%
data['PredictedGenre'] = my_guesses

# %%
data.head()
# Out:
#    year      artist.inverted                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre date.entered date.peaked  x1st.week  x2nd.week  x3rd.week  ...  \
# 0  Rock   2000-09-23  2000-11-18         78       63.0       49.0  ...
# 1  Rock   2000-02-12  2000-04-08         15        8.0        6.0  ...
# 2  Rock   1999-10-23  2000-01-29         71       48.0       43.0  ...
# 3  Rock   2000-08-12  2000-09-16         41       23.0       18.0  ...
# 4  Rock   2000-08-05  2000-10-14         57       47.0       45.0  ...
#
#    x68th.week  x69th.week  x70th.week  x71st.week  x72nd.week  x73rd.week  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    x74th.week  x75th.week  x76th.week  PredictedGenre
# 0         NaN         NaN         NaN         Country
# 1         NaN         NaN         NaN     Electronica
# 2         NaN         NaN         NaN           Latin
# 3         NaN         NaN         NaN           Latin
# 4         NaN         NaN         NaN             Rap
#
# [5 rows x 84 columns]

# %%
results = pd.crosstab(data['PredictedGenre'], data['genre'])
results
# Out:
# genre           Country  Electronica  Gospel  Jazz  Latin  Pop  R&B  Rap  \
# PredictedGenre
# Country              21            1       1     0      2    1    6   13
# Electronica           1            0       0     0      0    0    0    0
# Gospel                0            0       0     0      0    1    0    0
# Latin                18            1       0     1      1    0    7   10
# Pop                   1            0       0     0      0    0    0    3
# R&B                   0            0       0     0      0    0    0    0
# Rap                   8            1       0     0      1    2    0    8
# Reggae                0            0       0     0      0    0    0    0
# Rock                 25            1       0     0      5    5   10   24
#
# genre           Reggae  Rock
# PredictedGenre
# Country              0    25
# Electronica          0     7
# Gospel               0     0
# Latin                0    37
# Pop                  1     4
# R&B                  0     1
# Rap                  0    11
# Reggae               0     1
# Rock                 0    51

# %%
results.sum().sum()
# Out:
# 317

# %%
# Taking the sum of the diagonal will sum up the "correct" responses:

np.diag(results).sum()
# Out:
# 22

# %%
# Pandas can give us the sum of the entire table (note this is the same as the length - there is one count for each song)
total = results.sum().sum()
total
# Out:
# 317

# %%
# "raw" accuracy is the proportion correct out of the total:
np.diag(results).sum()/results.sum().sum()
# Out:
# 0.0694006309148265

# %%
# randomly guessing a genre would give us a 1 in 9 chance of getting it right
1/9
# Out:
# 0.1111111111111111

# %% [markdown]
# model is doing worse than chance level!! (As we would expect with fake random data)

# %% [markdown]
# ## Reading in another dataframe with ground truth
#
# Note if you are reading in another dataframe with ground truth you will have one label per file. You'll need to make sure that your data is organized the same way before you merge or concatenate your datasets

# %%
# E.g., (do-over to illustrate)

bb = pd.read_csv('../lessons/billboard.csv', encoding='latin-1')
bb.head()
# Out:
#    year      artist.inverted                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I  3:38
# 1  2000              Santana                           Maria, Maria  4:18
# 2  2000        Savage Garden                     I Knew I Loved You  4:07
# 3  2000              Madonna                                  Music  3:45
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)  3:38
#
#   genre date.entered date.peaked  x1st.week  x2nd.week  x3rd.week  ...  \
# 0  Rock   2000-09-23  2000-11-18         78       63.0       49.0  ...
# 1  Rock   2000-02-12  2000-04-08         15        8.0        6.0  ...
# 2  Rock   1999-10-23  2000-01-29         71       48.0       43.0  ...
# 3  Rock   2000-08-12  2000-09-16         41       23.0       18.0  ...
# 4  Rock   2000-08-05  2000-10-14         57       47.0       45.0  ...
#
#    x67th.week  x68th.week  x69th.week  x70th.week  x71st.week  x72nd.week  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#    x73rd.week  x74th.week  x75th.week  x76th.week
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN
#
# [5 rows x 83 columns]

# %%
sorted = bb.sort_values('artist.inverted')
#notice this will not change the indices:
sorted.head()
# Out:
#      year artist.inverted                                              track  \
# 246  2000           2 Pac                Baby Don't Cry (Keep Ya Head Up II)
# 287  2000         2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...
# 24   2000    3 Doors Down                                         Kryptonite
# 193  2000    3 Doors Down                                              Loser
# 69   2000        504 Boyz                                      Wobble Wobble
#
#      time genre date.entered date.peaked  x1st.week  x2nd.week  x3rd.week  \
# 246  4:22   Rap   2000-02-26  2000-03-11         87       82.0       72.0
# 287  3:15   R&B   2000-09-02  2000-09-09         91       87.0       92.0
# 24   3:53  Rock   2000-04-08  2000-11-11         81       70.0       68.0
# 193  4:24  Rock   2000-10-21  2000-12-02         76       76.0       72.0
# 69   3:35   Rap   2000-04-15  2000-05-06         57       34.0       25.0
#
#      ...  x67th.week  x68th.week  x69th.week  x70th.week  x71st.week  \
# 246  ...         NaN         NaN         NaN         NaN         NaN
# 287  ...         NaN         NaN         NaN         NaN         NaN
# 24   ...         NaN         NaN         NaN         NaN         NaN
# 193  ...         NaN         NaN         NaN         NaN         NaN
# 69   ...         NaN         NaN         NaN         NaN         NaN
#
#      x72nd.week  x73rd.week  x74th.week  x75th.week  x76th.week
# 246         NaN         NaN         NaN         NaN         NaN
# 287         NaN         NaN         NaN         NaN         NaN
# 24          NaN         NaN         NaN         NaN         NaN
# 193         NaN         NaN         NaN         NaN         NaN
# 69          NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 83 columns]

# %% [markdown]
# if I then try to append the 'myguesses' column of data, it will do so in the order of columns. We can see that the first row is assigned 'Country', then 'Electronica', and so on. Therefore **ensure your data are in the same order before you join**!!

# %%
sorted['PredictedGenre'] = my_guesses
sorted.head()
# Out:
#      year artist.inverted                                              track  \
# 246  2000           2 Pac                Baby Don't Cry (Keep Ya Head Up II)
# 287  2000         2Ge+her  The Hardest Part Of Breaking Up (Is Getting Ba...
# 24   2000    3 Doors Down                                         Kryptonite
# 193  2000    3 Doors Down                                              Loser
# 69   2000        504 Boyz                                      Wobble Wobble
#
#      time genre date.entered date.peaked  x1st.week  x2nd.week  x3rd.week  \
# 246  4:22   Rap   2000-02-26  2000-03-11         87       82.0       72.0
# 287  3:15   R&B   2000-09-02  2000-09-09         91       87.0       92.0
# 24   3:53  Rock   2000-04-08  2000-11-11         81       70.0       68.0
# 193  4:24  Rock   2000-10-21  2000-12-02         76       76.0       72.0
# 69   3:35   Rap   2000-04-15  2000-05-06         57       34.0       25.0
#
#      ...  x68th.week  x69th.week  x70th.week  x71st.week  x72nd.week  \
# 246  ...         NaN         NaN         NaN         NaN         NaN
# 287  ...         NaN         NaN         NaN         NaN         NaN
# 24   ...         NaN         NaN         NaN         NaN         NaN
# 193  ...         NaN         NaN         NaN         NaN         NaN
# 69   ...         NaN         NaN         NaN         NaN         NaN
#
#      x73rd.week  x74th.week  x75th.week  x76th.week  PredictedGenre
# 246         NaN         NaN         NaN         NaN         Country
# 287         NaN         NaN         NaN         NaN     Electronica
# 24          NaN         NaN         NaN         NaN           Latin
# 193         NaN         NaN         NaN         NaN           Latin
# 69          NaN         NaN         NaN         NaN             Rap
#
# [5 rows x 84 columns]

# %%
import librosa

librosa.load('../uploaded_audio/SO_DANCO_SAMBA.mp3')
# Out:
# /Users/carthur/PycharmProjects/audioTechII/at2venv/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# (array([0., 0., 0., ..., 0., 0., 0.], dtype=float32), 22050)

# %%
data, fs = librosa.load('../uploaded_audio/SO_DANCO_SAMBA.mp3')
# Out:
# /Users/carthur/PycharmProjects/audioTechII/at2venv/lib/python3.9/site-packages/librosa/core/audio.py:165: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)

# %%
import matplotlib.pyplot as plt

plt.plot(data)
